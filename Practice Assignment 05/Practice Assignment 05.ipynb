# %%
def is_divisible_by_k(x, k):
    '''
    Checks whether x is divisible by k.
    '''
    assert x%k == 0

# %%
'''
Store all the integers that are multiples of 2 or 5 or 7 
that are lower or equal to 1000 (excluding doubles)
'''
x = ()
for i in range(1000):
    if (is_divisible_by_k(x, 2) & is_divisible_by_k(x, 3)) | is_divisible_by_k(x, 7):
        x.append(i)
    
'''
Sum all the integers that are multiples of 2 or 5 or 7 
that are lower or equal to 1000 (excluding doubles)
'''
sum(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 7
#       5 x = ()
#       6 for i in range(1000):
# ----> 7     if (is_divisible_by_k(x, 2) & is_divisible_by_k(x, 3)) | is_divisible_by_k(x, 7):
#       8         x.append(i)
#      10 '''
#      11 Sum all the integers that are multiples of 2 or 5 or 7
#      12 that are lower or equal to 1000 (excluding doubles)
#      13 '''
#
# Cell In[19], line 2, in is_divisible_by_k(x, k)
#       1 def is_divisible_by_k(x, k):
# ----> 2     return x%k == 0
#
# TypeError: unsupported operand type(s) for %: 'tuple' and 'int'

# %% [markdown]
# ### Corrections

# %% [markdown]
# (1) Assert does not return the value of the function. Assert is used to debug code, stopping everytime x % k is not equal to 0

# %%
def is_divisible_by_k(x, k):
    return x%k == 0

# %% [markdown]
# <br>(2) x is initialise initially as a tuple that is not modifiable, thus change to list variable
# <br>(3) the for loop does not include the 1000, change to 1001 to include 1000.
# <br>(4) Syntax on condition for or is 'or' not '|', change '|' to 'or'
# <br>(5) If condition is logically wrong as it captures values mutiplies of 2 and 3 or 7, instead it should be all mutiples of 2,5,7
# <br>(6) If condition should be mutiplies of 2,5,7

# %%
x = []
for i in range(1001):
    if is_divisible_by_k(i, 2) or is_divisible_by_k(i, 5) or is_divisible_by_k(i, 7):
        x.append(i)

sum(x)
# Out:
# 328927
